# %% [markdown]
# <a href="https://colab.research.google.com/github/FernandoIGD12/UTEC_programming101/blob/main/Intro_AI/6_genetic_algortihms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Genetic Algorithms

# %% [markdown]
# # TSP problem

# %% [markdown]
# Plotting

# %%
import numpy as np
from scipy.spatial.distance import pdist, squareform
from matplotlib import pyplot as plt


def plot_tsp(nodes, route):
    """
    Plot the TSP nodes and route.

    Parameters:
    - nodes: List of tuples containing the coordinates of each node.
    - route: List of node indices representing the TSP route.
    """
    x = [node[0] for node in nodes]
    y = [node[1] for node in nodes]

    plt.figure(figsize=(8, 6))
    plt.scatter(x, y, color='blue', zorder=2)  # Plot nodes


    for i in range(len(route) - 1):
        node1 = route[i]
        node2 = route[i + 1]
        plt.plot([nodes[node1][0], nodes[node2][0]], [nodes[node1][1], nodes[node2][1]], color='red', zorder=1)  # Plot route

    # Connect the last node to the first node to form a loop
    node1 = route[-1]
    node2 = route[0]
    plt.plot([nodes[node1][0], nodes[node2][0]], [nodes[node1][1], nodes[node2][1]], color='red', zorder=1)  # Plot route

    plt.xlabel('X')
    plt.ylabel('Y')
    plt.title('TSP Nodes and Route')
    plt.grid(True)
    plt.show()

# %% [markdown]
# Cities and distancess

# %%
N = 10 # num cities
pop_size = 8 # population size
cities = np.random.rand(N, 2)
distances = squareform(pdist(cities, 'euclidean'))
#print(positions)
#print(distances)

# %% [markdown]
# #Population initialization

# %%
import random
import numpy as np

# Create initial population
def create_initial_population(pop_size, num_cities):
    population = []
    for _ in range(pop_size):
        individual = list(np.random.permutation(num_cities)) # create a random solution
        #individual = list(range(num_cities))
        #random.shuffle(individual)
        population.append(individual)
    return population

def fitness(solution): # depende del problema
  distance = 0
  for i in range(len(solution)-1):
    distance += distances[solution[i]][solution[i+1]]
  return distance

population = create_initial_population(pop_size, N)
print(population, "\n\n")
plot_tsp(cities, population[0])
print(fitness(population[0]))
plot_tsp(cities, population[2])
print(fitness(population[2]))
plot_tsp(cities, population[4])
# Out:
# [[np.int64(4), np.int64(6), np.int64(7), np.int64(5), np.int64(9), np.int64(2), np.int64(1), np.int64(3), np.int64(8), np.int64(0)], [np.int64(2), np.int64(0), np.int64(9), np.int64(8), np.int64(7), np.int64(5), np.int64(1), np.int64(6), np.int64(4), np.int64(3)], [np.int64(6), np.int64(2), np.int64(0), np.int64(1), np.int64(5), np.int64(4), np.int64(3), np.int64(7), np.int64(8), np.int64(9)], [np.int64(5), np.int64(1), np.int64(6), np.int64(4), np.int64(0), np.int64(8), np.int64(9), np.int64(3), np.int64(2), np.int64(7)], [np.int64(9), np.int64(8), np.int64(4), np.int64(3), np.int64(0), np.int64(6), np.int64(1), np.int64(7), np.int64(5), np.int64(2)], [np.int64(8), np.int64(2), np.int64(1), np.int64(0), np.int64(7), np.int64(3), np.int64(6), np.int64(5), np.int64(4), np.int64(9)], [np.int64(8), np.int64(3), np.int64(1), np.int64(2), np.int64(5), np.int64(6), np.int64(9), np.int64(0), np.int64(4), np.int64(7)], [np.int64(0), np.int64(4), np.int64(1), np.int64(2), np.int64(9), np.int64(3), np.int64(7), np.int64(8), np.int64(6), np.int64(5)]]
# 4.152633789874026
# 3.58483099280756

# %% [markdown]
# # Selection

# %% [markdown]
# Roulette Wheel Selection

# %%
# Selection: Roulette Wheel Selection for maximization
def roulete_wheel_selection(population, all_fitness):
    total_fitness = sum(all_fitness)
    selection_probs = [f / total_fitness for f in all_fitness]  # it works for maximization
    return population[np.random.choice(len(population), p=selection_probs)]


all_fitness = [ fitness(sol) for sol in population]
 # obtiene el fitness para cada inviduo
print("Population size:", len(population))
print("Num. cities:", N)
print(population)
print(all_fitness, "\n")

print("SELECTED IN MAXIMIZATION")
selected =  roulete_wheel_selection(population, all_fitness)
print("selected:", selected, fitness(selected), "\n")



def roulete_wheel_selection_minimization(population, all_fitness):
    max_fitness = max(all_fitness)
    inverted_fitness = [max_fitness - f for f in all_fitness]  # invert fitness
    total_fitness = sum(inverted_fitness)
    selection_probs = [f / total_fitness for f in inverted_fitness]
    return population[np.random.choice(len(population), p=selection_probs)]

print("SELECTED IN MINIMIZATION")
selected =  roulete_wheel_selection_minimization(population, all_fitness)
print("selected:", selected, fitness(selected), "\n")
# Out:
# Population size: 8
# Num. cities: 10
# [[np.int64(4), np.int64(6), np.int64(7), np.int64(5), np.int64(9), np.int64(2), np.int64(1), np.int64(3), np.int64(8), np.int64(0)], [np.int64(2), np.int64(0), np.int64(9), np.int64(8), np.int64(7), np.int64(5), np.int64(1), np.int64(6), np.int64(4), np.int64(3)], [np.int64(6), np.int64(2), np.int64(0), np.int64(1), np.int64(5), np.int64(4), np.int64(3), np.int64(7), np.int64(8), np.int64(9)], [np.int64(5), np.int64(1), np.int64(6), np.int64(4), np.int64(0), np.int64(8), np.int64(9), np.int64(3), np.int64(2), np.int64(7)], [np.int64(9), np.int64(8), np.int64(4), np.int64(3), np.int64(0), np.int64(6), np.int64(1), np.int64(7), np.int64(5), np.int64(2)], [np.int64(8), np.int64(2), np.int64(1), np.int64(0), np.int64(7), np.int64(3), np.int64(6), np.int64(5), np.int64(4), np.int64(9)], [np.int64(8), np.int64(3), np.int64(1), np.int64(2), np.int64(5), np.int64(6), np.int64(9), np.int64(0), np.int64(4), np.int64(7)], [np.int64(0), np.int64(4), np.int64(1), np.int64(2), np.int64(9), np.int64(3), np.int64(7), np.int64(8), np.int64(6), np.int64(5)]]
# [np.float64(4.152633789874026), np.float64(3.31028606679464), np.float64(3.58483099280756), np.float64(4.349778583334192), np.float64(3.8321266380103443), np.float64(4.974496898017582), np.float64(4.58643384732481), np.float64(4.765421822715954)]
#
# SELECTED IN MAXIMIZATION
# selected: [np.int64(6), np.int64(2), np.int64(0), np.int64(1), np.int64(5), np.int64(4), np.int64(3), np.int64(7), np.int64(8), np.int64(9)] 3.58483099280756
#
# SELECTED IN MINIMIZATION
# selected: [np.int64(6), np.int64(2), np.int64(0), np.int64(1), np.int64(5), np.int64(4), np.int64(3), np.int64(7), np.int64(8), np.int64(9)] 3.58483099280756

# %% [markdown]
# #Crossover

# %% [markdown]
# Single point crossover

# %%
def single_point_crossover(parent1, parent2):
    """
    Parameters:
    parent1 (list): The first parent.
    parent2 (list): The second parent.

    Returns:
    offspring1, offspring2: Two offspring produced by the crossover.
    """
    # Choose a crossover point
    crossover_point = random.randint(1, len(parent1) - 1)

    # Create offspring by combining parts of the parents
    offspring1 = parent1[:crossover_point] + parent2[crossover_point:]
    offspring2 = parent2[:crossover_point] + parent1[crossover_point:]

    return offspring1, offspring2

offspring1, offspring2 = single_point_crossover(population[0], population[1])
print("Parents:", list(population[0]), list(population[1]))
print("Offspring:", offspring1, offspring2)
# Out:
# Parents: [np.int64(4), np.int64(6), np.int64(7), np.int64(5), np.int64(9), np.int64(2), np.int64(1), np.int64(3), np.int64(8), np.int64(0)] [np.int64(2), np.int64(0), np.int64(9), np.int64(8), np.int64(7), np.int64(5), np.int64(1), np.int64(6), np.int64(4), np.int64(3)]
# Offspring: [np.int64(4), np.int64(6), np.int64(7), np.int64(5), np.int64(7), np.int64(5), np.int64(1), np.int64(6), np.int64(4), np.int64(3)] [np.int64(2), np.int64(0), np.int64(9), np.int64(8), np.int64(9), np.int64(2), np.int64(1), np.int64(3), np.int64(8), np.int64(0)]

# %% [markdown]
# Ordered crossover

# %%
def fill_child(child, parent, end):
    size = len(parent)
    current_pos = (end + 1) % size
    for gene in parent:
        if gene not in child:
            child[current_pos] = gene
            current_pos = (current_pos + 1) % size

def ordered_crossover(parent1, parent2):
    size = len(parent1)
    child1, child2 = [-1]*size, [-1]*size # crea los hijos llenos de -1 al principio

    start, end = sorted(random.sample(range(size), 2))
    child1[start:end+1] = parent2[start:end+1]
    child2[start:end+1] = parent1[start:end+1]

    fill_child(child1, parent1, end)
    fill_child(child2, parent2, end)

    return child1, child2

offspring1, offspring2 = ordered_crossover(population[0], population[1])
print("Parents:", population[0], population[1])
print("Offspring:", offspring1, offspring2)
# Out:
# Parents: [np.int64(4), np.int64(6), np.int64(7), np.int64(5), np.int64(9), np.int64(2), np.int64(1), np.int64(3), np.int64(8), np.int64(0)] [np.int64(2), np.int64(0), np.int64(9), np.int64(8), np.int64(7), np.int64(5), np.int64(1), np.int64(6), np.int64(4), np.int64(3)]
# Offspring: [np.int64(3), np.int64(0), np.int64(9), np.int64(8), np.int64(4), np.int64(6), np.int64(7), np.int64(5), np.int64(2), np.int64(1)] [np.int64(3), np.int64(6), np.int64(7), np.int64(5), np.int64(2), np.int64(0), np.int64(9), np.int64(8), np.int64(1), np.int64(4)]

# %% [markdown]
# # Mutation

# %% [markdown]
# Swap mutation

# %%
def swap_mutate(individual):
  i, j = np.random.choice(len(individual), 2, replace=False) # two random indices
  new_individual = individual.copy()
  new_individual[i], new_individual[j] = individual[j], individual[i]
  return new_individual

mutated = swap_mutate(population[0])
print("Original: \t", population[0])
print("Mutated: \t", mutated)
# Out:
# Original: 	 [np.int64(4), np.int64(6), np.int64(7), np.int64(5), np.int64(9), np.int64(2), np.int64(1), np.int64(3), np.int64(8), np.int64(0)]
# Mutated: 	 [np.int64(4), np.int64(6), np.int64(8), np.int64(5), np.int64(9), np.int64(2), np.int64(1), np.int64(3), np.int64(7), np.int64(0)]

# %% [markdown]
# #Selection elite

# %% [markdown]
# We will select some of the previous generation

# %%
def select_elite(population, all_fitness, elite_size):   # selecciona los que tengan el menor fitness
  elite_indices = np.argsort(all_fitness)[:elite_size]
  return np.array(population)[elite_indices], elite_indices


all_fitness = [ fitness(sol) for sol in population]
selected_elite, indices = select_elite(population, all_fitness, 2)

print("Population:", population)
print("Fitness:", all_fitness)
print("Selected Elite:", selected_elite)
print("Selected indices:", indices)

# para imprimir con mejor vista
import pandas as pd
data = {'Population': population, 'Fitness': all_fitness}
df = pd.DataFrame(data)
print(df)
# Out:
# Population: [[np.int64(4), np.int64(6), np.int64(7), np.int64(5), np.int64(9), np.int64(2), np.int64(1), np.int64(3), np.int64(8), np.int64(0)], [np.int64(2), np.int64(0), np.int64(9), np.int64(8), np.int64(7), np.int64(5), np.int64(1), np.int64(6), np.int64(4), np.int64(3)], [np.int64(6), np.int64(2), np.int64(0), np.int64(1), np.int64(5), np.int64(4), np.int64(3), np.int64(7), np.int64(8), np.int64(9)], [np.int64(5), np.int64(1), np.int64(6), np.int64(4), np.int64(0), np.int64(8), np.int64(9), np.int64(3), np.int64(2), np.int64(7)], [np.int64(9), np.int64(8), np.int64(4), np.int64(3), np.int64(0), np.int64(6), np.int64(1), np.int64(7), np.int64(5), np.int64(2)], [np.int64(8), np.int64(2), np.int64(1), np.int64(0), np.int64(7), np.int64(3), np.int64(6), np.int64(5), np.int64(4), np.int64(9)], [np.int64(8), np.int64(3), np.int64(1), np.int64(2), np.int64(5), np.int64(6), np.int64(9), np.int64(0), np.int64(4), np.int64(7)], [np.int64(0), np.int64(4), np.int64(1), np.int64(2), np.int64(9), np.int64(3), np.int64(7), np.int64(8), np.int64(6), np.int64(5)]]
# Fitness: [np.float64(4.152633789874026), np.float64(3.31028606679464), np.float64(3.58483099280756), np.float64(4.349778583334192), np.float64(3.8321266380103443), np.float64(4.974496898017582), np.float64(4.58643384732481), np.float64(4.765421822715954)]
# Selected Elite: [[2 0 9 8 7 5 1 6 4 3]
#  [6 2 0 1 5 4 3 7 8 9]]
# Selected indices: [1 2]
#                        Population   Fitness
# 0  [4, 6, 7, 5, 9, 2, 1, 3, 8, 0]  4.152634
# 1  [2, 0, 9, 8, 7, 5, 1, 6, 4, 3]  3.310286
# 2  [6, 2, 0, 1, 5, 4, 3, 7, 8, 9]  3.584831
# 3  [5, 1, 6, 4, 0, 8, 9, 3, 2, 7]  4.349779
# 4  [9, 8, 4, 3, 0, 6, 1, 7, 5, 2]  3.832127
# 5  [8, 2, 1, 0, 7, 3, 6, 5, 4, 9]  4.974497
# 6  [8, 3, 1, 2, 5, 6, 9, 0, 4, 7]  4.586434
# 7  [0, 4, 1, 2, 9, 3, 7, 8, 6, 5]  4.765422

# %% [markdown]
# #Integration

# %%
history = []

# Genetic Algorithm
def genetic_algorithm(distance_matrix, mutation_rate, generations):
    num_cities = distance_matrix.shape[0]
    population = create_initial_population(pop_size, N) # population size and num cities
    all_fitness = [ fitness(sol) for sol in population]

    for generation in range(generations):
        new_population = []

        # Preserve elite individuals
        selected_elite, elite_indices = select_elite(population, all_fitness, elite_size)
        new_population.extend(selected_elite)

        # Create new population through crossover and mutation
        while len(new_population) < pop_size:
            parent1 = roulete_wheel_selection_minimization(population, all_fitness)
            parent2 = roulete_wheel_selection_minimization(population, all_fitness)
            child1, child2 = ordered_crossover(parent1, parent2)

            if random.random() < mutation_rate:
                child1 = swap_mutate(child1)
            if random.random() < mutation_rate:
                child2 = swap_mutate(child2)

            new_population.extend([child1, child2])

        population = new_population[:pop_size] # replace with new population
        all_fitness = [ fitness(sol) for sol in population]
        if generation % 50 == 0:
          print(f"Generation {generation} | Best distance: {min(all_fitness)}")
          history.append([generation, min(all_fitness)])


    best_route_index = np.argmin(all_fitness)
    best_route = population[best_route_index]
    best_distance = all_fitness[best_route_index]

    print(f"Final best distance: {best_distance}")
    return best_route, best_distance

# hyperparametros
pop_size = 100
N = 50
elite_size = 10
mutation_rate = 0.01
generations = 5000

#pop_size = 200
#N = 100
#elite_size = 50
#mutation_rate = 0.001
#generations = 10000

cities = np.random.rand(N, 2)
distances = squareform(pdist(cities, 'euclidean'))

best_route, best_distance = genetic_algorithm(distances, mutation_rate, generations)
plot_tsp(cities, best_route)
# Out:
# Generation 0 | Best distance: 20.609049794492666
# Generation 50 | Best distance: 12.926144414303117
# Generation 100 | Best distance: 10.408830538390353
# Generation 150 | Best distance: 9.104838626595097
# Generation 200 | Best distance: 8.094035204529778
# Generation 250 | Best distance: 7.686256145013641
# Generation 300 | Best distance: 7.274350034821723
# Generation 350 | Best distance: 6.75598526740365
# Generation 400 | Best distance: 6.60215195115525
# Generation 450 | Best distance: 6.52760200275683
# Generation 500 | Best distance: 6.510568671796885
# Generation 550 | Best distance: 6.481873227986623
# Generation 600 | Best distance: 6.465741623349957
# Generation 650 | Best distance: 6.414819171969737
# Generation 700 | Best distance: 6.226509649100396
# Generation 750 | Best distance: 6.208021880118239
# Generation 800 | Best distance: 6.208021880118239
# Generation 850 | Best distance: 6.208021880118239
# Generation 900 | Best distance: 6.208021880118239
# Generation 950 | Best distance: 6.208021880118239
# Generation 1000 | Best distance: 6.208021880118239
# Generation 1050 | Best distance: 6.049717860753534
# Generation 1100 | Best distance: 6.049717860753534
# Generation 1150 | Best distance: 6.049717860753534
# Generation 1200 | Best distance: 6.049717860753534
# Generation 1250 | Best distance: 6.023186173951902
# Generation 1300 | Best distance: 6.023186173951902
# Generation 1350 | Best distance: 6.023186173951902
# Generation 1400 | Best distance: 6.023186173951902
# Generation 1450 | Best distance: 6.016296272343097
# Generation 1500 | Best distance: 6.016296272343097
# Generation 1550 | Best distance: 6.016296272343097
# Generation 1600 | Best distance: 6.016296272343097
# Generation 1650 | Best distance: 6.016296272343097
# Generation 1700 | Best distance: 6.016296272343097
# Generation 1750 | Best distance: 6.015661974919712
# Generation 1800 | Best distance: 6.015661974919712
# Generation 1850 | Best distance: 6.015661974919712
# Generation 1900 | Best distance: 6.015661974919712
# Generation 1950 | Best distance: 6.015661974919712
# Generation 2000 | Best distance: 6.015661974919712
# Generation 2050 | Best distance: 5.963758891275426
# Generation 2100 | Best distance: 5.963758891275426
# Generation 2150 | Best distance: 5.963758891275426
# Generation 2200 | Best distance: 5.963758891275426
# Generation 2250 | Best distance: 5.963758891275426
# Generation 2300 | Best distance: 5.905077220825872
# Generation 2350 | Best distance: 5.905077220825872
# Generation 2400 | Best distance: 5.905077220825872
# Generation 2450 | Best distance: 5.905077220825872
# Generation 2500 | Best distance: 5.905077220825872
# Generation 2550 | Best distance: 5.905077220825872
# Generation 2600 | Best distance: 5.905077220825872
# Generation 2650 | Best distance: 5.905077220825872
# Generation 2700 | Best distance: 5.899205788017989
# Generation 2750 | Best distance: 5.870821983822797
# Generation 2800 | Best distance: 5.870821983822797
# Generation 2850 | Best distance: 5.870821983822797
# Generation 2900 | Best distance: 5.870821983822797
# Generation 2950 | Best distance: 5.870821983822797
# Generation 3000 | Best distance: 5.870821983822797
# Generation 3050 | Best distance: 5.870821983822797
# Generation 3100 | Best distance: 5.870821983822797
# Generation 3150 | Best distance: 5.750389143591433
# Generation 3200 | Best distance: 5.750389143591433
# Generation 3250 | Best distance: 5.750389143591433
# Generation 3300 | Best distance: 5.750389143591433
# Generation 3350 | Best distance: 5.750389143591433
# Generation 3400 | Best distance: 5.750389143591433
# Generation 3450 | Best distance: 5.750389143591433
# Generation 3500 | Best distance: 5.750389143591433
# Generation 3550 | Best distance: 5.750389143591433
# Generation 3600 | Best distance: 5.750389143591433
# Generation 3650 | Best distance: 5.653322400452392
# Generation 3700 | Best distance: 5.653322400452392
# Generation 3750 | Best distance: 5.653322400452392
# Generation 3800 | Best distance: 5.653322400452392
# Generation 3850 | Best distance: 5.653322400452392
# Generation 3900 | Best distance: 5.653322400452392
# Generation 3950 | Best distance: 5.653322400452392
# Generation 4000 | Best distance: 5.653322400452392
# Generation 4050 | Best distance: 5.653322400452392
# Generation 4100 | Best distance: 5.653322400452392
# Generation 4150 | Best distance: 5.653322400452392
# Generation 4200 | Best distance: 5.653322400452392
# Generation 4250 | Best distance: 5.653322400452392
# Generation 4300 | Best distance: 5.653322400452392
# Generation 4350 | Best distance: 5.653322400452392
# Generation 4400 | Best distance: 5.649383453086205
# Generation 4450 | Best distance: 5.649383453086205
# Generation 4500 | Best distance: 5.649383453086205
# Generation 4550 | Best distance: 5.649383453086205
# Generation 4600 | Best distance: 5.649383453086205
# Generation 4650 | Best distance: 5.649383453086205
# Generation 4700 | Best distance: 5.649383453086205
# Generation 4750 | Best distance: 5.649383453086205
# Generation 4800 | Best distance: 5.649383453086205
# Generation 4850 | Best distance: 5.649383453086205
# Generation 4900 | Best distance: 5.649383453086205
# Generation 4950 | Best distance: 5.649383453086205
# Final best distance: 5.649383453086205

# %%
from matplotlib import pyplot as plt

data = np.array(history)
x = data[:, 0]
y = data[:, 1]

plt.plot(x, y)
plt.xlabel('Generations')
plt.ylabel('Distance')
plt.title('Genetic Algorithm Progress')
plt.show()

# %% [markdown]
# # GA vs Hill Climbing vs Simulated Annealing

# %%
def get_neighbors(sol):
  neighbors = []
  for i in range(len(sol) - 1):
    for j in range(i + 1, len(sol)):
      new_sol = sol.copy()
      new_sol[i], new_sol[j] = new_sol[j], new_sol[i]
      neighbors.append(new_sol)

  return neighbors

def hill_climbing(sol):
  while True:
    #print("iteration:", sol)
    neighbors = get_neighbors(sol)
    best_neighbor = min(neighbors, key=fitness)

    if fitness(best_neighbor) < fitness(sol):
      sol = best_neighbor
    else:
      return sol

def random_neighbor(sol):
  i, j = np.random.choice(len(sol), 2, replace=False) # two random indices
  new_sol = sol.copy()
  new_sol[i], new_sol[j] = new_sol[j], new_sol[i]
  return new_sol

def accept(delta, T):
  if delta < 0:
    return True
  else:
    r = np.random.rand() # random value between [0, 1]
    if r < np.exp(-delta/T):
      return True
    else:
      return False

def simulated_annealing(T_max, T_min, cooling_rate):
  T = T_max
  x = initial_solution.copy()
  E = fitness(x)

  print("temperatura:", T)
  print("x", x)
  print("E", E, "\n")


  while (T > T_min) :
    x_new = random_neighbor(x)
    E_new = fitness(x_new)
    delta = E_new - E
    #print("iteration, T:", T, " delta:", delta)
    if accept(delta, T):
      x = x_new
      E = E_new

    T = T*cooling_rate

  return x

# %%
T_max = 1000
T_min = 0.000001
cooling_rate = 0.9999

# initial solution
initial_solution = np.array(list(range(N)))
np.random.shuffle(initial_solution)

sol1 = hill_climbing(initial_solution)
sol2 = simulated_annealing(T_max, T_min, cooling_rate)
sol3 = best_route

print("Hill Climbing distance", fitness(sol1))
print("Simulated Annealing distance", fitness(sol2))

plot_tsp(cities, initial_solution)
plot_tsp(cities, sol1)
plot_tsp(cities, sol2)
plot_tsp(cities, sol3)
# Out:
# temperatura: 1000
# x [34 13  8 42  2 36 43 31 33 11 27  6 47 26  0 32 35 45 18 10 49 28 14 39
#  24 37 46 22 38 44 23 19 17 15  3  9 30 21 41  1 20  5  4 12 25 40 48  7
#  29 16]
# E 25.887767311122996
#
# Hill Climbing distance 8.438802675178932
# Simulated Annealing distance 6.117550764996992

# %%
for sol in [sol1, sol2, sol3]: print(fitness(sol))
# Out:
# 8.438802675178932
# 6.117550764996992
# 5.649383453086205
